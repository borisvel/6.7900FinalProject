# %%
# !pip install einops ninja gdown
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 41 kB 353 kB/s
# ...
#      |████████████████████████████████| 145 kB 48.1 MB/s
# ...

# %%
# !nvidia-smi
# Out:
# Sun Dec 11 20:53:12 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  A100-SXM4-40GB      Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   33C    P0    51W / 400W |      0MiB / 40536MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !pip install torch==1.10.0+cu113 torchvision==0.11.1+cu113 torchaudio===0.10.0+cu113 -f https://download.pytorch.org/whl/cu113/torch_stable.html
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Looking in links: https://download.pytorch.org/whl/cu113/torch_stable.html
# ...
#      |██████████████▋                 | 834.1 MB 1.2 MB/s eta 0:14:06tcmalloc: large alloc 1147494400 bytes == 0x39a1a000 @  0x7fed03c0e615 0x5d6f4c 0x51edd1 0x51ef5b 0x4f750a 0x4997a2 0x4fd8b5 0x4997c7 0x4fd8b5 0x49abe4 0x4f5fe9 0x55e146 0x4f5fe9 0x55e146 0x4f5fe9 0x55e146 0x5d8868 0x5da092 0x587116 0x5d8d8c 0x55dc1e 0x55cd91 0x5d8941 0x49abe4 0x55cd91 0x5d8941 0x4990ca 0x5d8868 0x4997a2 0x4fd8b5 0x49abe4
# ...

# %%
from google.colab import drive
import os

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd "/content/drive/My Drive/6.7900 Final Project"
# Out:
# /content/drive/My Drive/6.7900 Final Project

# %%
# !git clone https://github.com/NVlabs/stylegan3.git
# Out:
# Cloning into 'stylegan3'...
# remote: Enumerating objects: 207, done.
# remote: Total 207 (delta 0), reused 0 (delta 0), pack-reused 207
# Receiving objects: 100% (207/207), 4.16 MiB | 12.46 MiB/s, done.
# Resolving deltas: 100% (101/101), done.

# %%
# %cd stylegan3
# !mkdir datasets
# Out:
# /content/drive/My Drive/6.7900 Final Project/stylegan3

# %%
# !python dataset_tool.py --source='./datasets/bayc_rgb' --dest='./datasets/bayc_rgb.zip'
# Out:
# 100% 10000/10000 [00:19<00:00, 504.40it/s]

# %%
# !python train.py --outdir='./training-runs' --cfg=stylegan3-r --data='./datasets/bayc_rgb.zip' \
    --gpus=1 --batch=32 --gamma=0.5 --mirror=1 --kimg=3000 --batch-gpu=16 --snap=10 \
    --resume=https://api.ngc.nvidia.com/v2/models/nvidia/research/stylegan3/versions/1/files/stylegan3-r-metfaces-1024x1024.pkl
# Out:
# Training options:
# {
#   "G_kwargs": {
#     "class_name": "training.networks_stylegan3.Generator",
#     "z_dim": 512,
#     "w_dim": 512,
#     "mapping_kwargs": {
#       "num_layers": 2
#     },
#     "channel_base": 65536,
#     "channel_max": 1024,
#     "magnitude_ema_beta": 0.9988915792636801,
#     "conv_kernel": 1,
#     "use_radial_filters": true
#   },
#   "D_kwargs": {
#     "class_name": "training.networks_stylegan2.Discriminator",
#     "block_kwargs": {
#       "freeze_layers": 0
#     },
#     "mapping_kwargs": {},
#     "epilogue_kwargs": {
#       "mbstd_group_size": 4
#     },
#     "channel_base": 32768,
#     "channel_max": 512
#   },
#   "G_opt_kwargs": {
#     "class_name": "torch.optim.Adam",
#     "betas": [
#       0,
#       0.99
#     ],
#     "eps": 1e-08,
#     "lr": 0.0025
#   },
#   "D_opt_kwargs": {
#     "class_name": "torch.optim.Adam",
#     "betas": [
#       0,
#       0.99
#     ],
#     "eps": 1e-08,
#     "lr": 0.002
#   },
# ...

# %%
# %cd stylegan3/
# Out:
# /content/drive/My Drive/6.7900 Final Project/stylegan3

# %%
# !unzip './datasets/unicorns_rgb.zip' -d './datasets/unicorns_rgb/'
# Out:
# Archive:  ./datasets/unicorns_rgb.zip
#  extracting: ./datasets/unicorns_rgb/unicorns_rgb/pic10.png
#  extracting: ./datasets/unicorns_rgb/unicorns_rgb/pic100.png
#  extracting: ./datasets/unicorns_rgb/unicorns_rgb/pic1000.png
#  extracting: ./datasets/unicorns_rgb/unicorns_rgb/pic1001.png
#  extracting: ./datasets/unicorns_rgb/unicorns_rgb/pic1002.png
#  extracting: ./datasets/unicorns_rgb/unicorns_rgb/pic1003.png
#  extracting: ./datasets/unicorns_rgb/unicorns_rgb/pic1004.png
#  extracting: ./datasets/unicorns_rgb/unicorns_rgb/pic1005.png
#  extracting: ./datasets/unicorns_rgb/unicorns_rgb/pic1006.png
#  extracting: ./datasets/unicorns_rgb/unicorns_rgb/pic1007.png
#  extracting: ./datasets/unicorns_rgb/unicorns_rgb/pic1008.png
#  extracting: ./datasets/unicorns_rgb/unicorns_rgb/pic1009.png
#  extracting: ./datasets/unicorns_rgb/unicorns_rgb/pic101.png
#  extracting: ./datasets/unicorns_rgb/unicorns_rgb/pic1010.png
#  extracting: ./datasets/unicorns_rgb/unicorns_rgb/pic1011.png
# ...

# %%
# !python dataset_tool.py --source='./datasets/combined/' --dest='./datasets/combined.zip'
# Out:
# 100% 12369/12369 [00:25<00:00, 487.97it/s]

# %%
# !python train.py --outdir='./training-runs' --cfg=stylegan3-r --data='./datasets/combined.zip' \
    --gpus=1 --batch=32 --gamma=0.5 --mirror=1 --kimg=400 --batch-gpu=16 --snap=10 \
    --resume='./training-runs/00002-stylegan3-r-bayc_rgb-gpus1-batch32-gamma0.5/network-snapshot-002360.pkl'
# Out:
# Training options:
# {
#   "G_kwargs": {
#     "class_name": "training.networks_stylegan3.Generator",
#     "z_dim": 512,
#     "w_dim": 512,
#     "mapping_kwargs": {
#       "num_layers": 2
#     },
#     "channel_base": 65536,
#     "channel_max": 1024,
#     "magnitude_ema_beta": 0.9988915792636801,
#     "conv_kernel": 1,
#     "use_radial_filters": true
#   },
#   "D_kwargs": {
#     "class_name": "training.networks_stylegan2.Discriminator",
#     "block_kwargs": {
#       "freeze_layers": 0
#     },
#     "mapping_kwargs": {},
#     "epilogue_kwargs": {
#       "mbstd_group_size": 4
#     },
#     "channel_base": 32768,
#     "channel_max": 512
#   },
#   "G_opt_kwargs": {
#     "class_name": "torch.optim.Adam",
#     "betas": [
#       0,
#       0.99
#     ],
#     "eps": 1e-08,
#     "lr": 0.0025
#   },
#   "D_opt_kwargs": {
#     "class_name": "torch.optim.Adam",
#     "betas": [
#       0,
#       0.99
#     ],
#     "eps": 1e-08,
#     "lr": 0.002
#   },
# ...
